# %%
# Run the numeric dataset creation and inspect results
from IPython.display import display
import pandas as pd

from ium_long_stay_patterns.src.helpers.create_numerical_dataset import create_numerical_dataset, merge_with_stats
from ium_long_stay_patterns.config import ProcessedCSV
# Out:
# 2026-01-03 18:00:08.097 | INFO     | ium_long_stay_patterns.config:<module>:12 - PROJ_ROOT path is: /home/matimat/IUM/ium-long-stay-patterns

# %%
# Create numeric-only dataframe
df_numeric = create_numerical_dataset(ProcessedCSV.LISTINGS.path)

print("Shape:", df_numeric.shape)
display(df_numeric.head())
# Out:
# Shape: (1464, 19)
#                     id    host_id  host_response_rate  host_acceptance_rate  \
# 0             30419466  135482103                0.86                  1.00
# 1             49982681   31290848                1.00                  1.00
# 2             48800718  113548208                1.00                  1.00
# 3  1101264403993187936  118181401                1.00                  1.00
# 4   883790710439607743    4899687                1.00                  0.99
#
#    host_is_superhost  host_listings_count  host_total_listings_count  \
# 0                  1                   20                         24
# 1                  0                  109                        119
# 2                  0                  237                        241
# 3                  1                    8                          9
# 4                  1                    3                          3
#
#    host_verifications   latitude  longitude  accommodates  bathrooms  \
# 0                   2  37.972510   23.72772            10        3.0
# 1                   3  37.975360   23.73172             2        1.0
# 2                   3  37.963410   23.71779             7        2.5
# 3                   2  37.980590   23.71446             7        3.5
# 4                   2  37.978738   23.73873             4        2.0
#
#    bedrooms  beds  price  number_of_reviews  instant_bookable  \
# 0       4.0   7.0  432.0                181                 1
# 1       1.0   2.0   72.0                 22                 1
# 2       3.0   3.0  151.0                138                 1
# 3       3.0   5.0  600.0                 35                 1
# 4       2.0   2.0  207.0                 74                 1
#
#    calculated_host_listings_count  reviews_per_month
# 0                              12               2.51
# 1                              70               0.53
# 2                              90               3.08
# 3                               8               3.56
# 4                               1               3.76

# %%
print(df_numeric.head(1))
# Out:
#          id    host_id  host_response_rate  host_acceptance_rate  \
# 0  30419466  135482103                0.86                   1.0
#
#    host_is_superhost  host_listings_count  host_total_listings_count  \
# 0                  1                   20                         24
#
#    host_verifications  latitude  longitude  accommodates  bathrooms  bedrooms  \
# 0                   2  37.97251   23.72772            10        3.0       4.0
#
#    beds  price  number_of_reviews  instant_bookable  \
# 0   7.0  432.0                181                 1
#
#    calculated_host_listings_count  reviews_per_month
# 0                              12               2.51

# %%
# Inspect missing / NaN values in the numeric DataFrame
nan_counts = df_numeric.isna().sum().sort_values(ascending=False)
nan_percent = (nan_counts / len(df_numeric) * 100).round(2)

nan_summary = pd.concat([nan_counts, nan_percent], axis=1)
nan_summary.columns = ["n_missing", "pct_missing"]

print("--- Missing values per column (desc) ---")
display(nan_summary)

print("--- Basic stats ---")
cols_to_exclude = ['id', 'host_id', 'latitude', 'longitude']
display(df_numeric.drop(columns=cols_to_exclude).describe())
# Out:
# --- Missing values per column (desc) ---
#                                 n_missing  pct_missing
# reviews_per_month                     239        16.33
# host_response_rate                    176        12.02
# beds                                   98         6.69
# bathrooms                              96         6.56
# price                                  96         6.56
# host_acceptance_rate                   83         5.67
# bedrooms                                5         0.34
# host_id                                 0         0.00
# id                                      0         0.00
# host_listings_count                     0         0.00
# host_is_superhost                       0         0.00
# accommodates                            0         0.00
# longitude                               0         0.00
# latitude                                0         0.00
# host_verifications                      0         0.00
# host_total_listings_count               0         0.00
# number_of_reviews                       0         0.00
# instant_bookable                        0         0.00
# calculated_host_listings_count          0         0.00
# --- Basic stats ---
#        host_response_rate  host_acceptance_rate  host_is_superhost  \
# count         1288.000000           1381.000000        1464.000000
# mean             0.981506              0.944757           0.411885
# std              0.100442              0.172961           0.492343
# min              0.000000              0.000000           0.000000
# 25%              1.000000              0.990000           0.000000
# 50%              1.000000              1.000000           0.000000
# 75%              1.000000              1.000000           1.000000
# max              1.000000              1.000000           1.000000
#
#        host_listings_count  host_total_listings_count  host_verifications  \
# count          1464.000000                1464.000000         1464.000000
# mean             27.719945                  38.612705            2.072404
# std              77.887063                 123.300974            0.442392
# min               1.000000                   1.000000            1.000000
# 25%               2.000000                   2.000000            2.000000
# 50%               6.000000                   7.000000            2.000000
# 75%              24.250000                  29.250000            2.000000
# max             906.000000                2058.000000            3.000000
#
#        accommodates    bathrooms     bedrooms        beds        price  \
# count   1464.000000  1368.000000  1459.000000  1366.00000  1368.000000
# mean       3.689208     1.214181     1.413297     1.99634   100.635965
# std        1.974823     0.497797     0.846109     1.40146   184.115213
# min        1.000000     0.000000     0.000000     0.00000    15.000000
# 25%        2.000000     1.000000     1.000000     1.00000    47.000000
# 50%        4.000000     1.000000     1.000000     2.00000    68.000000
# 75%        4.000000     1.000000     2.000000     2.00000   110.000000
# max       16.000000     5.000000     7.000000    18.00000  5844.000000
#
#        number_of_reviews  instant_bookable  calculated_host_listings_count  \
# count        1464.000000       1464.000000                     1464.000000
# mean           53.013661          0.659836                       14.160519
# std            90.577096          0.473926                       22.611269
# min             0.000000          0.000000                        1.000000
# 25%             2.000000          0.000000                        1.000000
# 50%            15.000000          1.000000                        4.000000
# 75%            60.000000          1.000000                       15.000000
# max           831.000000          1.000000                      125.000000
#
#        reviews_per_month
# count        1225.000000
# mean            1.757992
# std             1.677437
# min             0.010000
# 25%             0.480000
# 50%             1.140000
# 75%             2.630000
# max            10.770000

# %% [markdown]
# Część danych zawiera Nany (ze względu na braki w danych lub informacje o ich braku 'N/A') więc odpowiednio to obsłużymy.

# %% [markdown]
# # Strategia
# 1. reviews_per_month -> fill(o)
# 2. host_response_rate & host_acceptance_rate -> average()
# 3. beds, bedrooms, bathrooms -> mediana
# 4. price -> drop (bo cena jest dość mocno skorelowana z zmienna celu, więc nie powinniśmy wprowadzać szumu)

# %%
# Create numeric-only dataframe (with strategy to handle NaNs)
df_numeric_v2 = create_numerical_dataset(ProcessedCSV.LISTINGS.path,strategy=True)


# Sprawdzenie czy coś zostało
print(df_numeric_v2.isna().sum())
# print("-----------------")
# # print("Shape:", df_numeric.shape)
# display(df_numeric_v2.head())
# Out:
# id                                0
# host_id                           0
# host_response_rate                0
# host_acceptance_rate              0
# host_is_superhost                 0
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# latitude                          0
# longitude                         0
# accommodates                      0
# bathrooms                         0
# bedrooms                          0
# beds                              0
# price                             0
# number_of_reviews                 0
# instant_bookable                  0
# calculated_host_listings_count    0
# reviews_per_month                 0
# dtype: int64

# %% [markdown]
# # Mergujemy atrybuty z listings z statystykami

# %%
df_numeric = create_numerical_dataset(ProcessedCSV.LISTINGS.path, strategy=True)

# 2. Łączymy ze statystykami i dodajemy target
df_final = merge_with_stats(df_numeric)

# 3. Weryfikacja
print(f"Kształt danych: {df_final.shape}")
print("\nRozkład długich pobytów:")
print(df_final['target'].value_counts())

with pd.option_context('display.max_columns', None):
    display(df_final.head())
# Out:
# Kształt danych: (1368, 19)
#
# Rozkład długich pobytów:
# target
# 0    994
# 1    374
# Name: count, dtype: int64
#    host_response_rate  host_acceptance_rate  host_is_superhost  \
# 0                0.86                  1.00                  1
# 1                1.00                  1.00                  0
# 2                1.00                  1.00                  0
# 3                1.00                  1.00                  1
# 4                1.00                  0.99                  1
#
#    host_listings_count  host_total_listings_count  host_verifications  \
# 0                   20                         24                   2
# 1                  109                        119                   3
# 2                  237                        241                   3
# 3                    8                          9                   2
# 4                    3                          3                   2
#
#     latitude  longitude  accommodates  bathrooms  bedrooms  beds  price  \
# 0  37.972510   23.72772            10        3.0       4.0   7.0  432.0
# 1  37.975360   23.73172             2        1.0       1.0   2.0   72.0
# 2  37.963410   23.71779             7        2.5       3.0   3.0  151.0
# 3  37.980590   23.71446             7        3.5       3.0   5.0  600.0
# 4  37.978738   23.73873             4        2.0       2.0   2.0  207.0
#
#    number_of_reviews  instant_bookable  calculated_host_listings_count  \
# 0                181                 1                              12
# 1                 22                 1                              70
# 2                138                 1                              90
# 3                 35                 1                               8
# 4                 74                 1                               1
#
#    reviews_per_month  total_bookings  target
# 0               2.51              19       0
# 1               0.53               4       1
# 2               3.08              15       0
# 3               3.56               2       0
# 4               3.76               7       0
